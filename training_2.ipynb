# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msn
import pandas as pd
import os
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import time
from sklearn import model_selection
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, StackingClassifier
from sklearn.model_selection import RandomizedSearchCV
import xgboost
import lightgbm as lgb
from sklearn import tree
import seaborn as sns
import matplotlib.pyplot as plt
import time
# Deep learning libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Input, Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from seaborn import load_dataset

# %%
# directory = './'
# Archive('../input/kkbox-music-recommendation-challenge/train.csv.7z').extractall(directory)
# Archive('../input/kkbox-music-recommendation-challenge/test.csv.7z').extractall(directory)
# Archive('../input/kkbox-music-recommendation-challenge/songs.csv.7z').extractall(directory)
# Archive('../input/kkbox-music-recommendation-challenge/members.csv.7z').extractall(directory)
# Archive('../input/kkbox-music-recommendation-challenge/song_extra_info.csv.7z').extractall(directory)

train = pd.read_csv('./copy_final_train2.csv')
test = pd.read_csv('./copy_final_test2.csv')
# songs = pd.read_csv('./songs.csv')
# members = pd.read_csv('./members.csv')
# songs_extra = pd.read_csv('./song_extra_info.csv')

# %%
# print(train.head())
# print(test.head())

# %%
# cat_list = ['msno', 'song_id', 'source_system_tab', 'source_screen_name', 'source_type', 'gender', 'registration_init_time', 'expiration_date', 'name', 'artist_name', 'country_code', 'registration_code']
# for col in cat_list:
#     train[col] = train[col].astype('category')
#     # test[col] = test[col].astype('category')

# %%
# X = train.drop(['target'], axis=1)
# y = train['target'].values

# X_test = test.drop(['id'], axis=1)
# ids = test['id'].values

# %%
# print(X.shape)
# Out:
# (7377418, 31)

# %%
# print(y.shape)
# Out:
# (7377418,)

# %%
# print(X_test.shape)
# Out:
# (2556790, 20)

# %%
# import gc
# gc.collect()
# train_set = lgb.Dataset(X , y)

# %%
# params = {
#         'objective': 'binary',
#         'metric': 'binary_logloss',
#         'boosting': 'gbdt',
#         'learning_rate': 0.3 ,
#         'verbose': 0,
#         'num_leaves': 108,
#         'bagging_fraction': 0.95,
#         'bagging_freq': 1,
#         'bagging_seed': 1,
#         'feature_fraction': 0.9,
#         'feature_fraction_seed': 1,
#         'max_bin': 256,
#         'max_depth': 10,
#         'num_rounds': 200,
#         'metric' : 'auc'
#     }

# %time model_f1 = lgb.train(params, train_set=train_set,  valid_sets=train_set, verbose_eval=5)
# Out:
# C:\Users\vhchu\anaconda3\envs\tensorflow\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_rounds` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# C:\Users\vhchu\anaconda3\envs\tensorflow\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.414822 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [5]	training's auc: 0.740108
# [10]	training's auc: 0.755094
# [15]	training's auc: 0.760885
# [20]	training's auc: 0.766242
# [25]	training's auc: 0.770361
# [30]	training's auc: 0.773787
# [35]	training's auc: 0.777062
# ...

# %%
# df = train.drop(['registration_init_time', 'expiration_date'], axis=1)
# cat_list = ['msno', 'song_id', 'source_system_tab', 'source_screen_name', \
# 'source_type', 'gender', 'name', 'artist_name', 'country_code', 'registration_code']
# df[cat_list] = df[cat_list].apply(LabelEncoder().fit_transform)
# df = df[cat_list]
# df = df.dropna()

# transformer = make_column_transformer(
#     (OneHotEncoder(), cat_list),
#     remainder='passthrough')

# transformer = make_column_transformer(
#     (LabelEncoder(), cat_list),
#     remainder='passthrough')

# for i in cat_list:

#     df[i].apply(LabelEncoder().fit_transform)

# transformed = transformer.fit_transform(df)
# transformed_df = pd.DataFrame(transformed)#, columns=transformer.get_feature_names())
# print(transformed_df.head())

# %%
# df

# %%
# df2 = test.drop(['id', 'registration_init_time', 'expiration_date'], axis=1)
# cat_list = ['msno', 'song_id', 'source_system_tab', 'source_screen_name', \
# 'source_type', 'gender', 'name', 'artist_name', 'country_code', 'registration_code']

# # df2 = df2.dropna()

# df2[cat_list] = df2[cat_list].apply(LabelEncoder().fit_transform)

# %%
# df2

# %%
df1 = train.drop(['target','registration_init_time', 'expiration_date'], axis=1)
df2 = test.drop(['id', 'registration_init_time', 'expiration_date'], axis=1)

df = pd.concat([df1, df2], axis=0)

# %%
cat_list = ['msno', 'song_id', 'source_system_tab', 'source_screen_name', \
'source_type', 'gender', 'name', 'artist_name', 'country_code', 'registration_code']

# df2 = df2.dropna()

df[cat_list] = df[cat_list].apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#           msno  song_id  source_system_tab  source_screen_name  source_type  \
# 0         9176    86884                  2                   7            7
# 1        19273   260594                  4                   8            5
# 2        19273   140755                  4                   8            5
# 3        19273    27577                  4                   8            5
# 4         9176    38706                  2                   7            7
# ...        ...      ...                ...                 ...          ...
# 2556785  19206   396079                  1                  11            7
# 2556786  25753   146146                  1                  22            7
# 2556787  25753   409892                  1                  22            7
# 2556788  25753   226660                  1                  22            7
# 2556789  25753   288315                  1                  22            7
#
# ...

# %%
from sklearn import preprocessing

x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
arr_scaled = min_max_scaler.fit_transform(df) 

df = pd.DataFrame(arr_scaled, columns=df.columns,index=df.index)
# df = pd.DataFrame(min_max_scaler.fit_transform(df.T), columns=df.columns, index=df.index)

# %%
df
# Out:
#              msno   song_id  source_system_tab  source_screen_name  \
# 0        0.266729  0.206946              0.250            0.318182
# 1        0.560229  0.620701              0.500            0.363636
# 2        0.560229  0.335260              0.500            0.363636
# 3        0.560229  0.065685              0.500            0.363636
# 4        0.266729  0.092193              0.250            0.318182
# ...           ...       ...                ...                 ...
# 2556785  0.558281  0.943409              0.125            0.500000
# 2556786  0.748590  0.348101              0.125            1.000000
# 2556787  0.748590  0.976310              0.125            1.000000
# 2556788  0.748590  0.539875              0.125            1.000000
# 2556789  0.748590  0.686729              0.125            1.000000
#
#          source_type      city        bd  gender  registered_via      name  \
# 0           0.583333  0.000000  0.055759     1.0        0.307692  0.223824
# ...

# %%
df1 = df.iloc[0:7377418,:]
df1
# Out:
#              msno   song_id  source_system_tab  source_screen_name  \
# 0        0.266729  0.206946              0.250            0.318182
# 1        0.560229  0.620701              0.500            0.363636
# 2        0.560229  0.335260              0.500            0.363636
# 3        0.560229  0.065685              0.500            0.363636
# 4        0.266729  0.092193              0.250            0.318182
# ...           ...       ...                ...                 ...
# 7377413  0.137376  0.520996              0.500            0.363636
# 7377414  0.593047  0.985425              0.875            0.772727
# 7377415  0.593047  0.142893              0.875            0.772727
# 7377416  0.039852  0.284105              0.125            0.227273
# 7377417  0.039852  0.343104              0.125            0.227273
#
#          source_type      city        bd  gender  registered_via      name  \
# 0           0.583333  0.000000  0.055759     1.0        0.307692  0.223824
# ...

# %%
df2 = df.iloc[7377418:,:]
df2
# Out:
#              msno   song_id  source_system_tab  source_screen_name  \
# 0        0.515203  0.543595              0.500            0.363636
# 1        0.515203  0.969514              0.500            0.363636
# 2        0.028400  0.167234              0.125            1.000000
# 3        0.054590  0.998223              0.750            0.727273
# 4        0.054590  0.381328              0.750            0.727273
# ...           ...       ...                ...                 ...
# 2556785  0.558281  0.943409              0.125            0.500000
# 2556786  0.748590  0.348101              0.125            1.000000
# 2556787  0.748590  0.976310              0.125            1.000000
# 2556788  0.748590  0.539875              0.125            1.000000
# 2556789  0.748590  0.686729              0.125            1.000000
#
#          source_type      city        bd  gender  registered_via      name  \
# 0           0.333333  0.000000  0.054845     1.0        0.307692  0.833829
# ...

# %%
df2.isna().sum()
# Out:
# msno                     0
# song_id                  0
# source_system_tab        0
# source_screen_name       0
# source_type              0
# city                     0
# bd                       0
# gender                   0
# registered_via           0
# name                     0
# artist_name              0
# language                 0
# song_duration_minutes    0
# genre_id                 0
# month                    0
# day                      0
# year                     0
# ex_month                 0
# ex_day                   0
# ex_year                  0
# ex_dayofweek             0
# country_code             0
# registration_code        0
# song_year                0
# member_song_count        0
# artist_song_count        0
# lang_song_count          0
# song_member_count        0
# age_song_count           0
# dtype: int64

# %%
# df.head()
# transformed_df.head()

# %%
from sklearn.model_selection import train_test_split
X = df1
y = train['target'].values
# X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, shuffle=False)# random_state=42)
X_train, y_train = X, y

# %%
X_test = df2

# %%
from sklearn import svm
clf_svm = svm.SVC()
clf_svm.fit(X_train, y_train)

# %%
y_pred = clf_svm.predict(X_test)
# y_pred = clf_svm.predict(X_test)
submission = pd.read_csv('sample_submission.csv')
submission['target'] = y_pred
submission.to_csv('submission_svm.csv', index= False)

# %%
from sklearn.tree import DecisionTreeClassifier
clf_dt = DecisionTreeClassifier()
clf_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf_dt.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_pred = clf_dt.predict(X_test)
submission = pd.read_csv('sample_submission.csv')
submission['target'] = y_pred
submission
# Out:
#               id  target
# 0              0       0
# 1              1       0
# 2              2       0
# 3              3       0
# 4              4       0
# ...          ...     ...
# 2556785  2556785       0
# 2556786  2556786       0
# 2556787  2556787       0
# 2556788  2556788       0
# 2556789  2556789       0
#
# [2556790 rows x 2 columns]

# %%
submission.to_csv('submission_dt.csv', index= False)

# %%
clf_dt.score(X_test, y_test)
# Out:
# 0.5786826559962697

# %%
from sklearn.metrics import classification_report, confusion_matrix
predicted_dt= clf_dt.predict(X_test)
print(confusion_matrix(y_test, predicted_dt))
print(classification_report(y_test, predicted_dt))
# Out:
# [[522396 356292]
#  [265355 331441]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.59      0.63    878688
#            1       0.48      0.56      0.52    596796
#
#     accuracy                           0.58   1475484
#    macro avg       0.57      0.57      0.57   1475484
# weighted avg       0.59      0.58      0.58   1475484

# %%
import time
import numpy as np
import pandas as pd

start_time = time.time()
importances = clf_dt.feature_importances_
elapsed_time = time.time() - start_time
# print(importances)
print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")

feature_names = list(df1)
# print(feature_names)
forest_importances = pd.Series(importances, index=list(feature_names))

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
# Out:
# Elapsed time to compute the importances: 0.028 seconds

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Random Forest Classifier
clf_rf = RandomForestClassifier()

# Train the model using the training sets
clf_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf_rf.predict(X_test)
submission = pd.read_csv('sample_submission.csv')
submission['target'] = y_pred
submission
# Out:
#               id  target
# 0              0       1
# 1              1       0
# 2              2       0
# 3              3       0
# 4              4       0
# ...          ...     ...
# 2556785  2556785       0
# 2556786  2556786       0
# 2556787  2556787       0
# 2556788  2556788       0
# 2556789  2556789       0
#
# [2556790 rows x 2 columns]

# %%
submission.to_csv('submission_rf.csv', index= False)

# %%
import pickle
filename = './models/dt_model.sav'
pickle.dump(clf_dt, open(filename, 'wb'))
filename = './models/rf_model.sav'
pickle.dump(clf_rf, open(filename, 'wb'))

# loaded_model = pickle.load(open(filename, 'rb'))

# %%
clf_rf.score(X_test, y_test)
# Out:
# 0.6402949811722798

# %%
from sklearn.metrics import classification_report, confusion_matrix
predicted_rf= clf_rf.predict(X_test)

print(confusion_matrix(y_test, predicted_rf))
print(classification_report(y_test, predicted_rf))
# Out:
# [[590486 288202]
#  [242537 354259]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69    878688
#            1       0.55      0.59      0.57    596796
#
#     accuracy                           0.64   1475484
#    macro avg       0.63      0.63      0.63   1475484
# weighted avg       0.65      0.64      0.64   1475484

# %%
# Feature importance in Random Forest
import time
import numpy as np
import pandas as pd

start_time = time.time()
importances = clf_rf.feature_importances_
# print(importances)
std = np.std([tree.feature_importances_ for tree in clf_rf.estimators_], axis=0)
elapsed_time = time.time() - start_time

print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")

feature_names = list(df1)
# print(feature_names)
forest_importances = pd.Series(importances, index=list(feature_names))

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
# Out:
# Elapsed time to compute the importances: 3.010 seconds

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
# Neural network
model = Sequential()
model.add(Dense(1, input_dim=29, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 30
# ...
# Total params: 30
# Trainable params: 30
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=50000,
    decay_rate=0.9)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),batch_size= 512, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 11528/11528 [==============================] - 19s 2ms/step - loss: 0.6853 - accuracy: 0.5622 - val_loss: 0.6949 - val_accuracy: 0.5386
# Epoch 2/100
# 11528/11528 [==============================] - 17s 1ms/step - loss: 0.6695 - accuracy: 0.6101 - val_loss: 0.6887 - val_accuracy: 0.5614
# Epoch 3/100
# 11528/11528 [==============================] - 17s 1ms/step - loss: 0.6659 - accuracy: 0.6135 - val_loss: 0.6895 - val_accuracy: 0.5625
# Epoch 4/100
# 11528/11528 [==============================] - 17s 1ms/step - loss: 0.6652 - accuracy: 0.6134 - val_loss: 0.6890 - val_accuracy: 0.5634
# Epoch 5/100
# 11528/11528 [==============================] - 17s 1ms/step - loss: 0.6650 - accuracy: 0.6131 - val_loss: 0.6888 - val_accuracy: 0.5636
# Epoch 6/100
# 11528/11528 [==============================] - 17s 1ms/step - loss: 0.6650 - accuracy: 0.6131 - val_loss: 0.6905 - val_accuracy: 0.5616
# Epoch 7/100
# ...

# %%
model.save('./models/sing_per.h5')

# %%
from matplotlib import pyplot
# evaluate the model
# _, train_acc = model.evaluate(X_train, y_train, batch_size= 512, verbose=0)
# _, test_acc = model.evaluate(X_test, y_test, batch_size= 512, verbose=0)
# print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
import pickle
with open('./trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

# %%
history2 = pickle.load(open('./trainHistoryDict', "rb"))
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history2['loss'], label='train')
pyplot.plot(history2['val_loss'], label='test')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history2['accuracy'], label='train')
pyplot.plot(history2['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
# Neural network
model = Sequential()
model.add(Dense(24, input_dim=29, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 24)                720
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                400
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 5
# ...
# Total params: 1,297
# Trainable params: 1,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=5e-3,
    decay_steps=500000,
    decay_rate=0.9)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
history3 = model.fit(X_train, y_train, validation_data=(X_test, y_test),batch_size= 128, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 46109/46109 [==============================] - 93s 2ms/step - loss: 0.6307 - accuracy: 0.6555 - val_loss: 0.6632 - val_accuracy: 0.6051
# Epoch 2/100
# 46109/46109 [==============================] - 91s 2ms/step - loss: 0.6256 - accuracy: 0.6599 - val_loss: 0.6708 - val_accuracy: 0.6016
# Epoch 3/100
# 46109/46109 [==============================] - 91s 2ms/step - loss: 0.6239 - accuracy: 0.6610 - val_loss: 0.6568 - val_accuracy: 0.6061
# Epoch 4/100
# 46109/46109 [==============================] - 92s 2ms/step - loss: 0.6231 - accuracy: 0.6617 - val_loss: 0.6618 - val_accuracy: 0.6031
# Epoch 5/100
# 46109/46109 [==============================] - 93s 2ms/step - loss: 0.6222 - accuracy: 0.6621 - val_loss: 0.6612 - val_accuracy: 0.6072
# Epoch 6/100
# 46109/46109 [==============================] - 91s 2ms/step - loss: 0.6219 - accuracy: 0.6627 - val_loss: 0.6580 - val_accuracy: 0.6086
# Epoch 7/100
# ...

# %%
model.save('./models/fully_connected.h5')

# %%
history3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17972\2975373910.py in <module>
# ----> 1 history3
#
# NameError: name 'history3' is not defined

# %%
X_train.shape
# Out:
# (5901934, 29)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout
# Neural network
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(29, 1)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(512, input_dim=29, activation='relu'))
# model.add(Dense(16, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.4))
model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.4))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_3 (Conv1D)           (None, 27, 32)            128
#
#  conv1d_4 (Conv1D)           (None, 25, 64)            6208
#
#  conv1d_5 (Conv1D)           (None, 23, 64)            12352
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 704)               0
#
#  dense_6 (Dense)             (None, 512)               360960
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 1)                 33
#
# ...
# Total params: 554,241
# Trainable params: 554,241
# Non-trainable params: 0
# ...

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=500000,
    decay_rate=0.9)
opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
history5 = model.fit(X_train, y_train, batch_size= 128, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 57637/57637 [==============================] - 366s 6ms/step - loss: 0.6243 - accuracy: 0.6556
# Epoch 2/100
# 57637/57637 [==============================] - 353s 6ms/step - loss: 0.6021 - accuracy: 0.6746
# Epoch 3/100
# 57637/57637 [==============================] - 378s 7ms/step - loss: 0.5847 - accuracy: 0.6890
# Epoch 4/100
# 57637/57637 [==============================] - 377s 7ms/step - loss: 0.5722 - accuracy: 0.6991
# Epoch 5/100
# 57637/57637 [==============================] - 376s 7ms/step - loss: 0.5630 - accuracy: 0.7066
# Epoch 6/100
# 57637/57637 [==============================] - 373s 6ms/step - loss: 0.5561 - accuracy: 0.7120
# Epoch 7/100
# 57637/57637 [==============================] - 374s 6ms/step - loss: 0.5505 - accuracy: 0.7163
# Epoch 8/100
# 57637/57637 [==============================] - 373s 6ms/step - loss: 0.5458 - accuracy: 0.7198
# Epoch 9/100
# 57637/57637 [==============================] - 373s 6ms/step - loss: 0.5421 - accuracy: 0.7228
# ...

# %%
model.save('./models/conv_net_final.h5')

# %%
import pickle
with open('./trainHistoryDict6', 'wb') as file_pi:
        pickle.dump(history5.history, file_pi)

# %%
model = keras.models.load_model('./models/conv_net_final.h5')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_3 (Conv1D)           (None, 27, 32)            128
#
#  conv1d_4 (Conv1D)           (None, 25, 64)            6208
#
#  conv1d_5 (Conv1D)           (None, 23, 64)            12352
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 704)               0
#
#  dense_6 (Dense)             (None, 512)               360960
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 1)                 33
#
# ...
# Total params: 554,241
# Trainable params: 554,241
# Non-trainable params: 0
# ...

# %%
y_pred = model.predict(X_test,batch_size= 64, verbose=1)
submission = pd.read_csv('sample_submission.csv')
submission['target'] = y_pred
print(submission)
submission.to_csv('submission_convnet.csv', index= False)
# Out:
# 39950/39950 [==============================] - 81s 2ms/step
#               id    target
# 0              0  0.370780
# 1              1  0.435146
# 2              2  0.193506
# 3              3  0.144653
# 4              4  0.110375
# ...          ...       ...
# 2556785  2556785  0.230699
# 2556786  2556786  0.290354
# 2556787  2556787  0.139313
# 2556788  2556788  0.188062
# 2556789  2556789  0.116803
#
# [2556790 rows x 2 columns]

# %%
score = model.evaluate(X_test, y_test,batch_size= 64, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 23055/23055 [==============================] - 84s 3ms/step - loss: 0.8667 - accuracy: 0.6266
# Test loss: 0.866651713848114
# Test accuracy: 0.6265835762023926

# %%
y2 = np.expand_dims(y_test, axis=1)
y2.shape
# Out:
# (1475484, 1)

# %%
y_pred
# Out:
# array([[0.65858364],
#        [0.6610605 ],
#        [0.596916  ],
#        ...,
#        [0.92543036],
#        [0.9998486 ],
#        [0.6926285 ]], dtype=float32)

# %%
# from keras import np_utils
# tf.keras.utils.to_categorical(y_pred)
np.where(y_pred > 0.5, 1,0)
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
from sklearn import metrics
matrix = metrics.confusion_matrix(y2, np.where(y_pred > 0.5, 1,0))
matrix
# Out:
# array([[583337, 295351],
#        [255619, 341177]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=['0','1'])
disp.plot()
plt.show()

# %%
print(classification_report(y2, np.where(y_pred > 0.5, 1,0), target_names=['0','1']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68    878688
#            1       0.54      0.57      0.55    596796
#
#     accuracy                           0.63   1475484
#    macro avg       0.62      0.62      0.62   1475484
# weighted avg       0.63      0.63      0.63   1475484

# %%
matrix
# Out:
# array([[583337, 295351],
#        [255619, 341177]], dtype=int64)

# %%
model = keras.models.load_model('./models/conv_net_2.h5')
score = model.evaluate(X_test, y_test,batch_size= 64, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 23055/23055 [==============================] - 84s 4ms/step - loss: 0.7065 - accuracy: 0.4045
# Test loss: 0.7065057754516602
# Test accuracy: 0.40447473526000977

# %%
import pickle
history4 = pickle.load(open('./trainHistoryDict5', "rb"))
plt.subplot(211)
plt.title('Loss')
plt.plot(history4['loss'], label='train')
plt.plot(history4['val_loss'], label='test')
plt.legend()
# plot accuracy during training
plt.subplot(212)
plt.title('Accuracy')
plt.plot(history4['accuracy'], label='train')
plt.plot(history4['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
# parameters = {'num_leaves': [200, 250, 300]}
# lgb_estimator = lgb.LGBMClassifier(learning_rate = 0.2, max_depth = 10, num_leaves = 250, objective = 'binary', n_estimators=50)
# grid = model_selection.GridSearchCV(estimator = lgb_estimator, param_grid = parameters, cv = 2, scoring = 'roc_auc')
# grid.fit(X, y, verbose = 5, eval_set = [(X,y)], eval_metric = 'auc')
# print(grid.best_params_)
